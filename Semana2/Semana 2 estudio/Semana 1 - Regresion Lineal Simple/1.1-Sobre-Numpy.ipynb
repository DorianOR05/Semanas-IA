# %%
import time
import numpy as np
n = 100000000

# %%
# For Loop (Ciclos)

start = time.time()

suma = 0
for x in range(1,n+1):
    suma = suma + x

print('total: ',suma)

end = time.time()
print('tiempo: ' "{:.5f}".format(end - start))
# Out:
# total:  5000000050000000
# tiempo: 19.00974

# %%
# Numpy Sum (Vectorizacion)

start = time.time()

suma = 0
suma = np.sum(np.arange(n+1))

print('total: ',suma)

end = time.time()
print('tiempo: ' "{:.5f}".format(end - start))
# Out:
# total:  5000000050000000
# tiempo: 0.42757

# %%
# Serie Aritmetica (Formula)

start = time.time()

suma = 0
suma = (n*(n+1))/2

print('total: ',suma)

end = time.time()
print('tiempo: ' "{:.5f}".format(end - start))
# Out:
# total:  5000000050000000.0
# tiempo: 0.00043
